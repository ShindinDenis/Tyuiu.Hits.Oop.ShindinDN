// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания 20

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
// <br>Создать базовый класс Event в C#, который будет представлять организованные
// мероприятия. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.
// <b>Требования к базовому классу Event:</b>
// <br><b>• Атрибуты:</b> ID мероприятия (EventId), Название мероприятия (EventName),
// Дата проведения (Date).
// <br><b>• Методы:</b>
// <br>o RegisterParticipant(): метод для регистрации участника.
// <br>o NotifyParticipants(): метод для уведомления участников о мероприятии.
// <br>o GetEventDetails(): метод для получения деталей мероприятия.
// <br><b>Требования к производным классам:</b>
// 1. Конференция (Conference): Должна содержать дополнительные атрибуты,
// такие как Количество спикеров (SpeakersCount).
// Метод NotifyParticipants() должен быть переопределен для отправки
// уведомлений с программой конференции.
// 2. Фестиваль (Festival): Должна содержать дополнительные атрибуты, такие как
// Количество музыкальных групп (BandsCount).
// Метод RegisterParticipant() должен быть переопределен для регистрации
// участников с выбором интересующих музыкальных жанров.
// 3. Семинар (Seminar) (если требуется третий класс): Должна содержать
// дополнительные атрибуты, такие как Тематические области (Topics).
// Метод GetEventDetails() должен быть переопределен для отображения
// тематических областей семинара вместе с другими деталями мероприятия.
// ----
// #### Дополнительное задание
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) создайте явную реализации интерфейса и управление зависимостями

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;
using System.Collections.Generic;
using System.Linq;

public interface INotificationService
{
    void SendNotification(string recipient, string message);
}

public class EmailNotificationService : INotificationService
{
    public void SendNotification(string recipient, string message)
    {
        Console.WriteLine($"[EMAIL] Отправлено {recipient}: \"{message}\"");
    }
}

public class SmsNotificationService : INotificationService
{
    public void SendNotification(string recipient, string message)
    {
        Console.WriteLine($"[SMS] Отправлено {recipient}: \"{message}\"");
    }
}


public interface ITickeable
{
    decimal GetPrice();
    void SellTicket(string participant);
    int GetTicketsSold();
}


public class Event : ITickeable
{
    public int EventId { get; set; }
    public string EventName { get; set; }
    public DateTime Date { get; set; }
    public string Location { get; set; }
    private bool IsCancelled { get; set; }
    protected List<string> participants = new List<string>();

    public decimal TicketPrice { get; set; }
    public string Organizer { get; set; }
    public string EventType { get; protected set; } 

    private readonly INotificationService _notificationService;

    public Event(int eventId, string eventName, DateTime date, string location, decimal ticketPrice, string organizer, INotificationService notificationService)
    {
        EventId = eventId;
        EventName = eventName;
        Date = date;
        Location = location;
        TicketPrice = ticketPrice;
        Organizer = organizer;
        EventType = "General";
        IsCancelled = false;
        _notificationService = notificationService;
    }

    public void SetNewDate(DateTime newDate)
    {
        Date = newDate;
        Console.WriteLine($"\n[INFO] Дата мероприятия '{EventName}' изменена на {newDate.ToShortDateString()}.");
        NotifyParticipants("Внимание! Дата мероприятия изменилась.");
    }

    public bool RemoveParticipant(string participant)
    {
        if (participants.Contains(participant))
        {
            participants.Remove(participant);
            Console.WriteLine($"\n[INFO] Участник {participant} удален с мероприятия '{EventName}'.");
            return true;
        }
        Console.WriteLine($"\n[INFO] Участник {participant} не найден на мероприятии '{EventName}'.");
        return false;
    }
    
    public string GetOrganizerInfo()
    {
        return $"Мероприятие '{EventName}' организовано: {Organizer}.";
    }

    public virtual void RegisterParticipant(string participant)
    {
        if (IsCancelled)
        {
            Console.WriteLine($"Ошибка: Мероприятие '{EventName}' отменено, регистрация невозможна.");
            return;
        }
        participants.Add(participant);
        Console.WriteLine($"Участник {participant} успешно зарегистрирован на мероприятие '{EventName}'.");
    }

    public virtual void NotifyParticipants(string customMessage)
    {
        Console.WriteLine($"\nОтправка кастомного уведомления для {participants.Count} участников '{EventName}':");
        foreach (var p in participants)
        {
            _notificationService.SendNotification(p, customMessage);
        }
    }

    public virtual void NotifyParticipants()
    {
        NotifyParticipants($"Напоминаем о мероприятии '{EventName}' {Date.ToShortDateString()}");
    }

    public virtual void GetEventDetails()
    {
        Console.WriteLine($"\n--- Детали мероприятия ({EventType}) ---");
        Console.WriteLine($"ID: {EventId}");
        Console.WriteLine($"Название: {EventName}");
        Console.WriteLine($"Дата: {Date.ToShortDateString()}");
        Console.WriteLine($"Место: {Location}");
        Console.WriteLine($"Организатор: {Organizer}");
        Console.WriteLine($"Цена билета: {TicketPrice:N2} ₽"); 
        Console.WriteLine($"Статус: {(IsCancelled ? "ОТМЕНЕНО" : "Активно")}");
        Console.WriteLine($"Количество зарегистрированных участников: {participants.Count}");
    }
    
    public virtual void CancelEvent()
    {
        if (!IsCancelled)
        {
            IsCancelled = true;
            Console.WriteLine($"\n!!! ВАЖНО: Мероприятие '{EventName}' ОТМЕНЕНО.");
            NotifyParticipants($"СРОЧНО: Мероприятие '{EventName}' отменено.");
        }
    }

    public void CheckCapacity(int maxCapacity)
    {
        CheckCapacity(participants.Count, maxCapacity);
    }
    
    public void CheckCapacity(int current, int max)
    {
        if (current >= max)
        {
            Console.WriteLine($"[Capacity Check] Внимание! Мероприятие '{EventName}' достигло максимальной вместимости ({max}).");
        }
        else
        {
            Console.WriteLine($"[Capacity Check] Осталось мест: {max - current}.");
        }
    }

    public void AnnounceTo(Event otherEvent)
    {
        Console.WriteLine($"\nМероприятие '{EventName}' объявляет о сотрудничестве с '{otherEvent.EventName}'.");
    }
    
    
    decimal ITickeable.GetPrice()
    {
        return this.TicketPrice;
    }

    int ITickeable.GetTicketsSold()
    {
        return this.participants.Count;
    }

    void ITickeable.SellTicket(string participant)
    {
        if (TicketPrice > 0)
        {
            Console.WriteLine($"[TicketSystem] Продажа билета для {participant} на '{EventName}' за {TicketPrice:N2} ₽...");
            Console.WriteLine($"[TicketSystem] Оплата получена.");
        }
        else
        {
            Console.WriteLine($"[TicketSystem] Регистрация (бесплатно) для {participant} на '{EventName}'.");
        }
        
        this.RegisterParticipant(participant);
    }
}


public class Conference : Event
{
    public int SpeakersCount { get; set; }
    public string MainTopic { get; set; }
    public List<string> Sponsors { get; private set; }
    public Dictionary<TimeSpan, string> Schedule { get; private set; }
    public bool HasNetworkingEvent { get; set; }

    public Conference(int eventId, string eventName, DateTime date, string location, int speakersCount, string mainTopic, decimal ticketPrice, string organizer, INotificationService notificationService)
        : base(eventId, eventName, date, location, ticketPrice, organizer, notificationService)
    {
        SpeakersCount = speakersCount;
        MainTopic = mainTopic;
        EventType = "Conference"; 
        Sponsors = new List<string>();
        Schedule = new Dictionary<TimeSpan, string>();
    }
    
    public void AddSponsor(string sponsorName)
    {
        Sponsors.Add(sponsorName);
        Console.WriteLine($"\n[Sponsor] {sponsorName} теперь спонсор конференции '{EventName}'.");
    }

    public void AddScheduleItem(TimeSpan time, string description)
    {
        Schedule[time] = description;
        Console.WriteLine($"[Schedule] Добавлено в расписание {time}: {description}");
    }

    public void PrintSchedule()
    {
        Console.WriteLine($"\n--- Расписание для '{EventName}' ---");
        foreach (var item in Schedule.OrderBy(kv => kv.Key))
        {
            Console.WriteLine($"{item.Key} - {item.Value}");
        }
        Console.WriteLine("---------------------------------");
    }

    public override void NotifyParticipants()
    {
        NotifyParticipants($"Подготовлена программа конференции '{EventName}' с {SpeakersCount} спикерами по теме '{MainTopic}'.");
    }

    public override void GetEventDetails()
    {
        base.GetEventDetails();
        Console.WriteLine($"Количество спикеров: {SpeakersCount}");
        Console.WriteLine($"Основная тема: {MainTopic}");
        Console.WriteLine($"Нетворкинг: {(HasNetworkingEvent ? "Запланирован" : "Нет")}");
        if (Sponsors.Count > 0)
        {
            Console.WriteLine($"Спонсоры: {string.Join(", ", Sponsors)}");
        }
    }
    
    public override void CancelEvent()
    {
        base.CancelEvent();
        Console.WriteLine($"Спикерам и спонсорам отправлено уведомление об отмене конференции.");
    }
    
    public void ExchangeSpeakers(Conference otherConference)
    {
        Console.WriteLine($"\nКонференция '{EventName}' обменивается {SpeakersCount} спикерами с конференцией '{otherConference.EventName}' у которой {otherConference.SpeakersCount} спикеров.");
    }
}


public class Festival : Event
{
    public int BandsCount { get; set; }
    public bool HasFireworks { get; set; }
    public string MusicGenre { get; set; }
    public int AgeRating { get; set; }
    public int FoodTrucksCount { get; private set; }


    public Festival(int eventId, string eventName, DateTime date, string location, int bandsCount, bool hasFireworks, decimal ticketPrice, string organizer, string genre, int ageRating, INotificationService notificationService)
        : base(eventId, eventName, date, location, ticketPrice, organizer, notificationService)
    {
        BandsCount = bandsCount;
        HasFireworks = hasFireworks;
        MusicGenre = genre;
        AgeRating = ageRating;
        FoodTrucksCount = 0;
        EventType = "Festival";
    }
    
    public void AnnounceHeadliner(string bandName)
    {
        Console.WriteLine($"\n[HEADLINER] {bandName} выступит на фестивале '{EventName}'!");
        NotifyParticipants($"Срочная новость! {bandName} - хедлайнер фестиваля '{EventName}'!");
    }
    
    public bool CheckAge(int participantAge)
    {
        bool allowed = participantAge >= AgeRating;
        Console.WriteLine($"[Age Check] Возраст {participantAge}. Ограничение {AgeRating}+. Доступ: {(allowed ? "Разрешен" : "Запрещен")}");
        return allowed;
    }
    
    public void AddFoodTruck()
    {
        FoodTrucksCount++;
        Console.WriteLine($"[Info] На фестивале '{EventName}' теперь {FoodTrucksCount} фуд-траков.");
    }

    public void RegisterParticipant(string participant, string favoriteGenre)
    {
        base.RegisterParticipant(participant); 
        Console.WriteLine($"Любимый музыкальный жанр: {favoriteGenre}.");
    }

    public override void RegisterParticipant(string participant)
    {
        RegisterParticipant(participant, "Не указан");
    }

    public override void GetEventDetails()
    {
        base.GetEventDetails();
        Console.WriteLine($"Музыкальный жанр: {MusicGenre}");
        Console.WriteLine($"Количество музыкальных групп: {BandsCount}");
        Console.WriteLine($"Будет фейерверк: {(HasFireworks ? "Да" : "Нет")}");
        Console.WriteLine($"Возрастной рейтинг: {AgeRating}+");
        Console.WriteLine($"Кол-во фуд-траков: {FoodTrucksCount}");
    }
    
    public void PerformWith(Festival otherFestival)
    {
        Console.WriteLine($"\nФестиваль '{EventName}' и фестиваль '{otherFestival.EventName}' объединяют свои {BandsCount} и {otherFestival.BandsCount} группы для совместного выступления.");
    }
}


public class Seminar : Event
{
    public List<string> Topics { get; set; }
    public int MaxParticipants { get; set; }
    public string SpeakerName { get; set; }
    public double DurationHours { get; set; }
    public List<string> RequiredMaterials { get; set; }

    public Seminar(int eventId, string eventName, DateTime date, string location, List<string> topics, int maxParticipants, decimal ticketPrice, string organizer, string speaker, double duration, INotificationService notificationService)
        : base(eventId, eventName, date, location, ticketPrice, organizer, notificationService)
    {
        Topics = topics;
        MaxParticipants = maxParticipants;
        SpeakerName = speaker;
        DurationHours = duration;
        RequiredMaterials = new List<string>();
        EventType = "Seminar";
    }

    public void GetRequiredMaterialsList()
    {
        Console.WriteLine($"\nМатериалы для семинара '{EventName}':");
        if (RequiredMaterials.Count == 0)
        {
            Console.WriteLine("- Ничего не требуется.");
            return;
        }
        foreach (var material in RequiredMaterials)
        {
            Console.WriteLine($"- {material}");
        }
    }
    
    public void AddRequiredMaterial(string material)
    {
        RequiredMaterials.Add(material);
        Console.WriteLine($"[Info] Для семинара '{EventName}' теперь требуется: {material}.");
    }

    public string GetDuration()
    {
        return $"Семинар '{EventName}' продлится {DurationHours} ч.";
    }


    public override void GetEventDetails()
    {
        base.GetEventDetails();
        Console.WriteLine($"Спикер: {SpeakerName}");
        Console.WriteLine($"Продолжительность: {DurationHours} ч.");
        Console.WriteLine($"Макс. участников: {MaxParticipants}");
        Console.WriteLine("Темы семинара:");
        foreach (var topic in Topics)
        {
            Console.WriteLine($"- {topic}");
        }
        GetRequiredMaterialsList();
    }
    
    public override void RegisterParticipant(string participant)
    {
        if (participants.Count >= MaxParticipants)
        {
             Console.WriteLine($"Ошибка: Семинар '{EventName}' полон ({MaxParticipants} участников).");
             return;
        }
        base.RegisterParticipant(participant);
    }
    
    public void CollaborateOnTopic(Seminar otherSeminar)
    {
        Console.WriteLine($"\nСеминар '{EventName}' и семинар '{otherSeminar.EventName}' начинают совместную работу над темой '{Topics[0]}'.");
    }
}


public class EventManager<T> where T : Event
{
    private List<T> _events = new List<T>();
    public string ManagerName { get; private set; }

    public EventManager(string name)
    {
        ManagerName = name;
    }

    public void AddEvent(T eventItem)
    {
        _events.Add(eventItem);
    }

    public void RunAllEventDetails()
    {
        Console.WriteLine($"\n\n*** Менеджер {ManagerName}: Запуск отчетов (Полиморфизм) ***");
        foreach (var eventItem in _events)
        {
            eventItem.GetEventDetails(); 
        }
    }
}


INotificationService emailService = new EmailNotificationService();
INotificationService smsService = new SmsNotificationService();

Event generalEvent = new Event(101, "Общее собрание", new DateTime(2023, 11, 25), "Офис A", 0, "HR Отдел", emailService);
Conference techConference = new Conference(201, "Технологический форум", new DateTime(2023, 12, 10), "Павильон №1", 15, "ИИ и Автоматизация", 1500, "TechOrg", emailService);
Festival musicFestival = new Festival(301, "Summer Jam", new DateTime(2024, 6, 15), "Парк Горького", 20, true, 5000, "MusicFest Ltd.", "Rock", 18, smsService);
Seminar codingSeminar = new Seminar(401, "Мастер-класс по C#", new DateTime(2024, 1, 20), "Онлайн", new List<string> { "ООП", "LINQ", "Асинхронное программирование" }, 5, 1000, "IT-Univer", "Алексей Иванов", 4.5, emailService);

Conference securityConference = new Conference(202, "Конференция по кибербезопасности", new DateTime(2023, 12, 12), "Павильон №2", 10, "Защита данных", 2000, "SecureInc", emailService);
Festival rockFestival = new Festival(302, "Rock Fest", new DateTime(2024, 7, 20), "Стадион", 12, false, 4500, "MusicFest Ltd.", "Alternative", 16, smsService);
Seminar pythonSeminar = new Seminar(402, "Семинар по Python", new DateTime(2024, 2, 15), "Класс B", new List<string> { "Django", "Flask" }, 15, 0, "IT-Univer", "Мария Петрова", 3, emailService);

techConference.AddSponsor("МегаКорп");
techConference.AddScheduleItem(new TimeSpan(9, 0, 0), "Регистрация и кофе");
techConference.AddScheduleItem(new TimeSpan(10, 0, 0), "Keynote: Будущее ИИ");
techConference.PrintSchedule();

musicFestival.AddFoodTruck();
musicFestival.AddFoodTruck();
musicFestival.CheckAge(20); 
musicFestival.CheckAge(16); 

codingSeminar.AddRequiredMaterial("Visual Studio 2022");
codingSeminar.AddRequiredMaterial("Аккаунт .NET");
Console.WriteLine(codingSeminar.GetDuration());

Console.WriteLine(generalEvent.GetOrganizerInfo());
generalEvent.SetNewDate(new DateTime(2023, 11, 26)); 
generalEvent.RegisterParticipant("Иван");


Console.WriteLine("\n----------------------------------");
ITickeable ticketedFestival = (ITickeable)musicFestival;

Console.WriteLine($"Цена билета на {musicFestival.EventName}: {ticketedFestival.GetPrice():N2} ₽");
ticketedFestival.SellTicket("Александр"); 
ticketedFestival.SellTicket("Елена");

Console.WriteLine($"Билетов продано (через интерфейс): {ticketedFestival.GetTicketsSold()}");
musicFestival.GetEventDetails(); 

ITickeable freeSeminar = (ITickeable)pythonSeminar;
Console.WriteLine($"Цена билета на {pythonSeminar.EventName}: {freeSeminar.GetPrice():N2} ₽");
freeSeminar.SellTicket("Виктор"); 
pythonSeminar.GetEventDetails();


Console.WriteLine("\n----------------------------------");
        
techConference.RegisterParticipant("Анна");
techConference.NotifyParticipants(); 

musicFestival.RegisterParticipant("Сергей", "Рок"); 
musicFestival.NotifyParticipants(); 

codingSeminar.RegisterParticipant("Мария");
codingSeminar.GetEventDetails();
codingSeminar.NotifyParticipants(); 
        
generalEvent.AnnounceTo(techConference);
techConference.ExchangeSpeakers(securityConference);
musicFestival.PerformWith(rockFestival);
codingSeminar.CollaborateOnTopic(pythonSeminar);

techConference.CancelEvent(); 
        
EventManager<Event> manager = new EventManager<Event>("Глобальный");
manager.AddEvent(techConference);
manager.AddEvent(musicFestival);
manager.AddEvent(codingSeminar);
manager.AddEvent(generalEvent); 
        
manager.RunAllEventDetails();
// Out:
// [Sponsor] МегаКорп теперь спонсор конференции 'Технологический форум'.
// [Schedule] Добавлено в расписание 09:00:00: Регистрация и кофе
// [Schedule] Добавлено в расписание 10:00:00: Keynote: Будущее ИИ
//
// --- Расписание для 'Технологический форум' ---
// 09:00:00 - Регистрация и кофе
// 10:00:00 - Keynote: Будущее ИИ
// ---------------------------------
// [Info] На фестивале 'Summer Jam' теперь 1 фуд-траков.
// [Info] На фестивале 'Summer Jam' теперь 2 фуд-траков.
// [Age Check] Возраст 20. Ограничение 18+. Доступ: Разрешен
// [Age Check] Возраст 16. Ограничение 18+. Доступ: Запрещен
// [Info] Для семинара 'Мастер-класс по C#' теперь требуется: Visual Studio 2022.
// [Info] Для семинара 'Мастер-класс по C#' теперь требуется: Аккаунт .NET.
// Семинар 'Мастер-класс по C#' продлится 4,5 ч.
// Мероприятие 'Общее собрание' организовано: HR Отдел.
//
// [INFO] Дата мероприятия 'Общее собрание' изменена на 26.11.2023.
//
// Отправка кастомного уведомления для 0 участников 'Общее собрание':
// Участник Иван успешно зарегистрирован на мероприятие 'Общее собрание'.
//
// ----------------------------------
// Цена билета на Summer Jam: 5 000,00 ₽
// [TicketSystem] Продажа билета для Александр на 'Summer Jam' за 5 000,00 ₽...
// [TicketSystem] Оплата получена.
// Участник Александр успешно зарегистрирован на мероприятие 'Summer Jam'.
// Любимый музыкальный жанр: Не указан.
// [TicketSystem] Продажа билета для Елена на 'Summer Jam' за 5 000,00 ₽...
// [TicketSystem] Оплата получена.
// Участник Елена успешно зарегистрирован на мероприятие 'Summer Jam'.
// Любимый музыкальный жанр: Не указан.
// Билетов продано (через интерфейс): 2
//
// --- Детали мероприятия (Festival) ---
// ID: 301
// Название: Summer Jam
// Дата: 15.06.2024
// Место: Парк Горького
// Организатор: MusicFest Ltd.
// Цена билета: 5 000,00 ₽
// Статус: Активно
// Количество зарегистрированных участников: 2
// Музыкальный жанр: Rock
// Количество музыкальных групп: 20
// Будет фейерверк: Да
// Возрастной рейтинг: 18+
// Кол-во фуд-траков: 2
// Цена билета на Семинар по Python: 0,00 ₽
// [TicketSystem] Регистрация (бесплатно) для Виктор на 'Семинар по Python'.
// Участник Виктор успешно зарегистрирован на мероприятие 'Семинар по Python'.
//
// --- Детали мероприятия (Seminar) ---
// ID: 402
// Название: Семинар по Python
// Дата: 15.02.2024
// Место: Класс B
// Организатор: IT-Univer
// Цена билета: 0,00 ₽
// Статус: Активно
// Количество зарегистрированных участников: 1
// Спикер: Мария Петрова
// Продолжительность: 3 ч.
// Макс. участников: 15
// Темы семинара:
// - Django
// - Flask
//
// Материалы для семинара 'Семинар по Python':
// - Ничего не требуется.
//
// ----------------------------------
// Участник Анна успешно зарегистрирован на мероприятие 'Технологический форум'.
//
// Отправка кастомного уведомления для 1 участников 'Технологический форум':
// [EMAIL] Отправлено Анна: "Подготовлена программа конференции 'Технологический форум' с 15 спикерами по теме 'ИИ и Автоматизация'."
// Участник Сергей успешно зарегистрирован на мероприятие 'Summer Jam'.
// Любимый музыкальный жанр: Рок.
//
// Отправка кастомного уведомления для 3 участников 'Summer Jam':
// [SMS] Отправлено Александр: "Напоминаем о мероприятии 'Summer Jam' 15.06.2024"
// [SMS] Отправлено Елена: "Напоминаем о мероприятии 'Summer Jam' 15.06.2024"
// [SMS] Отправлено Сергей: "Напоминаем о мероприятии 'Summer Jam' 15.06.2024"
// Участник Мария успешно зарегистрирован на мероприятие 'Мастер-класс по C#'.
//
// --- Детали мероприятия (Seminar) ---
// ID: 401
// Название: Мастер-класс по C#
// Дата: 20.01.2024
// Место: Онлайн
// Организатор: IT-Univer
// Цена билета: 1 000,00 ₽
// Статус: Активно
// Количество зарегистрированных участников: 1
// Спикер: Алексей Иванов
// Продолжительность: 4,5 ч.
// Макс. участников: 5
// Темы семинара:
// - ООП
// - LINQ
// - Асинхронное программирование
//
// Материалы для семинара 'Мастер-класс по C#':
// - Visual Studio 2022
// - Аккаунт .NET
//
// Отправка кастомного уведомления для 1 участников 'Мастер-класс по C#':
// [EMAIL] Отправлено Мария: "Напоминаем о мероприятии 'Мастер-класс по C#' 20.01.2024"
//
// Мероприятие 'Общее собрание' объявляет о сотрудничестве с 'Технологический форум'.
//
// Конференция 'Технологический форум' обменивается 15 спикерами с конференцией 'Конференция по кибербезопасности' у которой 10 спикеров.
//
// Фестиваль 'Summer Jam' и фестиваль 'Rock Fest' объединяют свои 20 и 12 группы для совместного выступления.
//
// Семинар 'Мастер-класс по C#' и семинар 'Семинар по Python' начинают совместную работу над темой 'ООП'.
//
// !!! ВАЖНО: Мероприятие 'Технологический форум' ОТМЕНЕНО.
//
// Отправка кастомного уведомления для 1 участников 'Технологический форум':
// [EMAIL] Отправлено Анна: "СРОЧНО: Мероприятие 'Технологический форум' отменено."
// Спикерам и спонсорам отправлено уведомление об отмене конференции.
//
//
// *** Менеджер Глобальный: Запуск отчетов (Полиморфизм) ***
//
// --- Детали мероприятия (Conference) ---
// ID: 201
// Название: Технологический форум
// Дата: 10.12.2023
// Место: Павильон №1
// Организатор: TechOrg
// Цена билета: 1 500,00 ₽
// Статус: ОТМЕНЕНО
// Количество зарегистрированных участников: 1
// Количество спикеров: 15
// Основная тема: ИИ и Автоматизация
// Нетворкинг: Нет
// Спонсоры: МегаКорп
//
// --- Детали мероприятия (Festival) ---
// ID: 301
// Название: Summer Jam
// Дата: 15.06.2024
// Место: Парк Горького
// Организатор: MusicFest Ltd.
// Цена билета: 5 000,00 ₽
// Статус: Активно
// Количество зарегистрированных участников: 3
// Музыкальный жанр: Rock
// Количество музыкальных групп: 20
// Будет фейерверк: Да
// Возрастной рейтинг: 18+
// Кол-во фуд-траков: 2
//
// --- Детали мероприятия (Seminar) ---
// ID: 401
// Название: Мастер-класс по C#
// Дата: 20.01.2024
// Место: Онлайн
// Организатор: IT-Univer
// Цена билета: 1 000,00 ₽
// Статус: Активно
// Количество зарегистрированных участников: 1
// Спикер: Алексей Иванов
// Продолжительность: 4,5 ч.
// Макс. участников: 5
// Темы семинара:
// - ООП
// - LINQ
// - Асинхронное программирование
//
// Материалы для семинара 'Мастер-класс по C#':
// - Visual Studio 2022
// - Аккаунт .NET
//
// --- Детали мероприятия (General) ---
// ID: 101
// Название: Общее собрание
// Дата: 26.11.2023
// Место: Офис A
// Организатор: HR Отдел
// Цена билета: 0,00 ₽
// Статус: Активно
// Количество зарегистрированных участников: 1
